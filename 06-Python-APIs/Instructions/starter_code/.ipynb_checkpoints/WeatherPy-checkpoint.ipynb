# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
import sys
from decimal import *
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
print(lats.min())
print(lats.max())
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
        
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#print(cities)
# Out:
# -89.98609126250075
# 89.65982019591974
# 602

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66

# %%
weather_data_list = []
cities_count = len(cities)

print('Begining Data Retrieval')

for i in range(len(cities)):
    target_url=url+"&q="+cities[i]
    print(target_url)
    
    if (i+1)%60==0:
        print('Taking break for a min--------------------')
        time.sleep(61)
        
        
    
    print(f"processing record {i} of {cities_count}")
    response = requests.get(target_url).json()
    
    if(response['cod']!='404'): #skipping the records where the API return status code "404" Not Found Error
        
        country=response['sys']['country']
        
        date=response['dt']
        
        lattitude=response['coord']['lat'] #reads the latitiude from the JSON response
        
        longitude=response['coord']['lon'] 
        
        temperature=response['main']['temp_max'] #temperature
                
        humidity=response['main']['humidity'] #humidity %
                
        clouds=response['clouds']['all'] #Clouds %
        
        windspeed=response['wind']['speed']

        
        #Creating a dictionary with weather data
        weather_data_dictionary = {"City":cities[i],"Cloudiness":clouds,"Country":country,"Date":date,"Humidity":humidity,"Lat":lattitude,"Lng":longitude,"Max Temp":temperature,"Wind Speed":windspeed}
        weather_data_list.append(weather_data_dictionary)

print("All Done!----------")
city_data_df = pd.DataFrame(weather_data_list)
# Out:
# Begining Data Retrieval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=east london
# processing record 0 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=puerto ayora
# processing record 1 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ambodifototra
# processing record 2 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=velsk
# processing record 3 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cabo san lucas
# processing record 4 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=grand gaube
# processing record 5 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cape town
# processing record 6 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=chokurdakh
# processing record 7 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hermanus
# processing record 8 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=grindavik
# processing record 9 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vila franca do campo
# processing record 10 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hasaki
# processing record 11 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=albany
# processing record 12 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=domoni
# processing record 13 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tayu
# processing record 14 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=taolanaro
# processing record 15 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jamestown
# processing record 16 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mys shmidta
# processing record 17 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dandong
# processing record 18 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=belushya guba
# processing record 19 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=salalah
# processing record 20 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ushuaia
# processing record 21 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sumbe
# processing record 22 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=illoqqortoormiut
# processing record 23 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tiksi
# processing record 24 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cap malheureux
# processing record 25 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lakes entrance
# processing record 26 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=koslan
# processing record 27 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=palabuhanratu
# processing record 28 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=provideniya
# processing record 29 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=louisbourg
# processing record 30 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mataura
# processing record 31 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=esperance
# processing record 32 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kudahuvadhoo
# processing record 33 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=aklavik
# processing record 34 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=faya
# processing record 35 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=punta arenas
# processing record 36 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hithadhoo
# processing record 37 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=rikitea
# processing record 38 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ribeira grande
# processing record 39 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tuktoyaktuk
# processing record 40 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=paragominas
# processing record 41 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=qasigiannguit
# processing record 42 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=havre-saint-pierre
# processing record 43 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bafia
# processing record 44 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vaini
# processing record 45 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kupang
# processing record 46 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=arraial do cabo
# processing record 47 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tasiilaq
# processing record 48 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=qaanaaq
# processing record 49 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bredasdorp
# processing record 50 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nikolskoye
# processing record 51 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=luderitz
# processing record 52 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=avarua
# processing record 53 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=yellowknife
# processing record 54 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ngunguru
# processing record 55 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lebu
# processing record 56 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=la paz
# processing record 57 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=attawapiskat
# processing record 58 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tomatlan
# Taking break for a min--------------------
# processing record 59 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dikson
# processing record 60 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=teknaf
# processing record 61 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sao filipe
# processing record 62 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=souillac
# processing record 63 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=price
# processing record 64 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ust-kuyga
# processing record 65 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nizhneyansk
# processing record 66 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ferme-neuve
# processing record 67 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=orsha
# processing record 68 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kenai
# processing record 69 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=taseyevo
# processing record 70 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=alice springs
# processing record 71 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tabiauea
# processing record 72 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mar del plata
# processing record 73 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=leningradskiy
# processing record 74 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tuatapere
# processing record 75 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=asosa
# processing record 76 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ye
# processing record 77 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=clyde river
# processing record 78 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kolpashevo
# processing record 79 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=chernyshevskiy
# processing record 80 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=busselton
# processing record 81 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nanortalik
# processing record 82 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=biltine
# processing record 83 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mushie
# processing record 84 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=atuona
# processing record 85 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=fortuna
# processing record 86 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san policarpo
# processing record 87 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mehamn
# processing record 88 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=butaritari
# processing record 89 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mount isa
# processing record 90 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=victoria
# processing record 91 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=alanya
# processing record 92 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=malanje
# processing record 93 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hambantota
# processing record 94 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ponta do sol
# processing record 95 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lorengau
# processing record 96 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lompoc
# processing record 97 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pout
# processing record 98 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port alfred
# processing record 99 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lagoa
# processing record 100 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sibolga
# processing record 101 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bambanglipuro
# processing record 102 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bonavista
# processing record 103 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=champerico
# processing record 104 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jaszbereny
# processing record 105 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hobart
# processing record 106 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=puerto leguizamo
# processing record 107 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saint george
# processing record 108 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sinop
# processing record 109 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=polewali
# processing record 110 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bambous virieux
# processing record 111 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=rosario oeste
# processing record 112 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kalengwa
# processing record 113 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ancud
# processing record 114 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tawnat
# processing record 115 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vila velha
# processing record 116 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bluff
# processing record 117 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=wasaga beach
# processing record 118 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lodja
# Taking break for a min--------------------
# processing record 119 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kinablangan
# processing record 120 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=berlevag
# processing record 121 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=westport
# processing record 122 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kapaa
# processing record 123 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=marsh harbour
# processing record 124 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=flinders
# processing record 125 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=padang
# processing record 126 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=katsuura
# processing record 127 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=santiago del estero
# processing record 128 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=elblag
# processing record 129 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vranovice
# processing record 130 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ngukurr
# processing record 131 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tupiza
# processing record 132 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=buraydah
# processing record 133 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kozhva
# processing record 134 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sistranda
# processing record 135 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cherskiy
# processing record 136 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=korla
# processing record 137 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sillamae
# processing record 138 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saint-philippe
# processing record 139 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=faanui
# processing record 140 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=thompson
# processing record 141 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sitka
# processing record 142 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=russell
# processing record 143 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pacific grove
# processing record 144 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=harper
# processing record 145 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bull savanna
# processing record 146 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=barrow
# processing record 147 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=carutapera
# processing record 148 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port elizabeth
# processing record 149 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sabzevar
# processing record 150 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=husavik
# processing record 151 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=upernavik
# processing record 152 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=yulara
# processing record 153 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=torbay
# processing record 154 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=umm lajj
# processing record 155 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=namibe
# processing record 156 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=goderich
# processing record 157 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=castro
# processing record 158 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mazamari
# processing record 159 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=raudeberg
# processing record 160 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vaitupu
# processing record 161 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=umm kaddadah
# processing record 162 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=venezuela
# processing record 163 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=new norfolk
# processing record 164 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bathsheba
# processing record 165 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=gwadar
# processing record 166 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pisz
# processing record 167 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=preobrazhenskaya
# processing record 168 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sioux lookout
# processing record 169 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kaili
# processing record 170 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=atka
# processing record 171 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mullaitivu
# processing record 172 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=iqaluit
# processing record 173 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bossier city
# processing record 174 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sorland
# processing record 175 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=opuwo
# processing record 176 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sarangani
# processing record 177 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ketou
# processing record 178 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nagato
# Taking break for a min--------------------
# processing record 179 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=aketi
# processing record 180 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bengkulu
# processing record 181 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mahebourg
# processing record 182 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kresttsy
# processing record 183 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kavieng
# processing record 184 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mount gambier
# processing record 185 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=akyab
# processing record 186 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mantua
# processing record 187 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jaguaquara
# processing record 188 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=umm durman
# processing record 189 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sarkand
# processing record 190 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=aden
# processing record 191 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=longyearbyen
# processing record 192 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=gao
# processing record 193 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=luan
# processing record 194 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=brae
# processing record 195 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hay river
# processing record 196 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=paamiut
# processing record 197 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nouadhibou
# processing record 198 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vardo
# processing record 199 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=carballo
# processing record 200 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=roberto payan
# processing record 201 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sitapur
# processing record 202 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=khorixas
# processing record 203 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tautira
# processing record 204 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san quintin
# processing record 205 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=klaksvik
# processing record 206 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=qui nhon
# processing record 207 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=zanatepec
# processing record 208 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=copertino
# processing record 209 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=noumea
# processing record 210 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=iskateley
# processing record 211 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=college
# processing record 212 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=codrington
# processing record 213 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=viseu
# processing record 214 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kondinskoye
# processing record 215 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=natalio
# processing record 216 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=panuco
# processing record 217 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=baghdad
# processing record 218 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=carnarvon
# processing record 219 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=solovetskiy
# processing record 220 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port hardy
# processing record 221 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=haibowan
# processing record 222 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sainte-marie
# processing record 223 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=devils lake
# processing record 224 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=manokwari
# processing record 225 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=marcona
# processing record 226 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=shelburne
# processing record 227 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kodiak
# processing record 228 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=georgetown
# processing record 229 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=majene
# processing record 230 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vaitape
# processing record 231 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=quelimane
# processing record 232 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kaitangata
# processing record 233 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=camrose
# processing record 234 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=norman wells
# processing record 235 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saskylakh
# processing record 236 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sabang
# processing record 237 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=amderma
# processing record 238 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saldanha
# Taking break for a min--------------------
# processing record 239 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pitimbu
# processing record 240 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=la sarre
# processing record 241 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=laguna
# processing record 242 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lazaro cardenas
# processing record 243 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ilulissat
# processing record 244 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=high level
# processing record 245 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=fuengirola
# processing record 246 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=salinopolis
# processing record 247 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san patricio
# processing record 248 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hilo
# processing record 249 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cockburn town
# processing record 250 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=rocha
# processing record 251 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=launceston
# processing record 252 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=praia da vitoria
# processing record 253 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pevek
# processing record 254 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ossora
# processing record 255 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jining
# processing record 256 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=viligili
# processing record 257 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=panaba
# processing record 258 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=zolotinka
# processing record 259 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san juan
# processing record 260 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=manzhouli
# processing record 261 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=develi
# processing record 262 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=severo-kurilsk
# processing record 263 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sentyabrskiy
# processing record 264 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=piet retief
# processing record 265 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=general pico
# processing record 266 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dano
# processing record 267 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=montepuez
# processing record 268 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ketchikan
# processing record 269 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=zarand
# processing record 270 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vredendal
# processing record 271 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tsihombe
# processing record 272 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jacareacanga
# processing record 273 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=geraldton
# processing record 274 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=polunochnoye
# processing record 275 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=narsaq
# processing record 276 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sangar
# processing record 277 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=asau
# processing record 278 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san rafael
# processing record 279 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=quang ngai
# processing record 280 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=qiryat shemona
# processing record 281 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=meulaboh
# processing record 282 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tabou
# processing record 283 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ahipara
# processing record 284 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=chuy
# processing record 285 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=itarema
# processing record 286 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nong kung si
# processing record 287 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=eldikan
# processing record 288 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=zykovo
# processing record 289 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bilibino
# processing record 290 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sena madureira
# processing record 291 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pisco
# processing record 292 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sao joao da barra
# processing record 293 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=wadi musa
# processing record 294 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=menongue
# processing record 295 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=malaya vishera
# processing record 296 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=teguldet
# processing record 297 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port-gentil
# processing record 298 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port lincoln
# Taking break for a min--------------------
# processing record 299 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bosaso
# processing record 300 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=karratha
# processing record 301 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=filingue
# processing record 302 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=barinas
# processing record 303 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mizdah
# processing record 304 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=srednekolymsk
# processing record 305 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=brainerd
# processing record 306 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=vydrino
# processing record 307 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=barentsburg
# processing record 308 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dharchula
# processing record 309 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kharan
# processing record 310 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=abu dhabi
# processing record 311 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=samarai
# processing record 312 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mokobeng
# processing record 313 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=talnakh
# processing record 314 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=clarence town
# processing record 315 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jhunjhunun
# processing record 316 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=baturaja
# processing record 317 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mimongo
# processing record 318 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hirara
# processing record 319 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dinsor
# processing record 320 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=libreville
# processing record 321 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=aykhal
# processing record 322 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ukiah
# processing record 323 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=khatanga
# processing record 324 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=yumen
# processing record 325 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=khuzhir
# processing record 326 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=surgut
# processing record 327 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cidreira
# processing record 328 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=takoradi
# processing record 329 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sampit
# processing record 330 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kapit
# processing record 331 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ismailia
# processing record 332 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=requena
# processing record 333 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jahrom
# processing record 334 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=muravlenko
# processing record 335 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kautokeino
# processing record 336 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cabo rojo
# processing record 337 of 602
# ...
# processing record 489 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saryozek
# processing record 490 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=chalus
# processing record 491 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=karonga
# processing record 492 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kazalinsk
# processing record 493 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hukuntsi
# processing record 494 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san jeronimo
# processing record 495 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ridgetown
# processing record 496 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=harrison
# processing record 497 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hunza
# processing record 498 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cape girardeau
# processing record 499 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=san andres
# processing record 500 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=zyryanka
# processing record 501 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ostrovnoy
# processing record 502 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=massakory
# processing record 503 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=linjiang
# processing record 504 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=susanville
# processing record 505 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nalut
# processing record 506 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=awbari
# processing record 507 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=serebryanyy bor
# processing record 508 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=xai-xai
# processing record 509 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tubruq
# processing record 510 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=suoyarvi
# processing record 511 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=cururupu
# processing record 512 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pasighat
# processing record 513 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tahoua
# processing record 514 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mayor pablo lagerenza
# processing record 515 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=birjand
# processing record 516 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sobolevo
# processing record 517 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=boulder city
# processing record 518 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=svetlyy
# processing record 519 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=beira
# processing record 520 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nadym
# processing record 521 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=sogdiondon
# processing record 522 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bagli
# processing record 523 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=havoysund
# processing record 524 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=concepcion del uruguay
# processing record 525 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tambun
# processing record 526 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=yar-sale
# processing record 527 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=acajutla
# processing record 528 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=wanning
# processing record 529 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=savonlinna
# processing record 530 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=agirish
# processing record 531 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tilichiki
# processing record 532 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=caraballeda
# processing record 533 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=dingle
# processing record 534 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=chama
# processing record 535 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=acapulco
# processing record 536 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kulu
# processing record 537 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bilma
# processing record 538 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=coihaique
# Taking break for a min--------------------
# processing record 539 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=xianyang
# processing record 540 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=oktyabrskoye
# processing record 541 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=samusu
# processing record 542 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=madimba
# processing record 543 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bur gabo
# processing record 544 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=risaralda
# processing record 545 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=katangli
# processing record 546 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=alofi
# processing record 547 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=secunda
# processing record 548 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=constitucion
# processing record 549 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ucluelet
# processing record 550 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=wulanhaote
# processing record 551 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=wampusirpi
# processing record 552 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=port moresby
# processing record 553 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=baiyin
# processing record 554 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saurimo
# processing record 555 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=moose factory
# processing record 556 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=poum
# processing record 557 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=beyneu
# processing record 558 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=khani
# processing record 559 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=matara
# processing record 560 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nipawin
# processing record 561 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=xiongyue
# processing record 562 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nueve de julio
# processing record 563 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=lolua
# processing record 564 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ijaki
# processing record 565 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=broken hill
# processing record 566 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=nome
# processing record 567 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=yangjiang
# processing record 568 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kesinga
# processing record 569 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=rorvik
# processing record 570 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=orje
# processing record 571 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=constantine
# processing record 572 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mirsid
# processing record 573 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=alta floresta
# processing record 574 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=feni
# processing record 575 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ambunti
# processing record 576 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=abalak
# processing record 577 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ambuclao
# processing record 578 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ingleside
# processing record 579 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=bekhtery
# processing record 580 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=stornoway
# processing record 581 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=registro
# processing record 582 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=ondorhaan
# processing record 583 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=stoyba
# processing record 584 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=pitsunda
# processing record 585 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=hami
# processing record 586 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=laakirchen
# processing record 587 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=taltal
# processing record 588 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=umzimvubu
# processing record 589 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mogadishu
# processing record 590 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=tripoli
# processing record 591 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=gondar
# processing record 592 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kutum
# processing record 593 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=jalali
# processing record 594 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=waitati
# processing record 595 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=kozan
# processing record 596 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=saint-leu
# processing record 597 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=katha
# processing record 598 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=mianyang
# Taking break for a min--------------------
# processing record 599 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=juneau
# processing record 600 of 602
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=902c261024299a24bf88a314f144db66&q=strathmore
# processing record 601 of 602

# %%
city_data_df.count()
# Out:
# City          532
# Cloudiness    532
# Country       532
# Date          532
# Humidity      532
# Lat           532
# Lng           532
# Max Temp      532
# Wind Speed    532
# dtype: int64

# %%
city_data_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     east london           0      ZA  1535235886        94 -33.02   27.91
# 1    puerto ayora          75      EC  1535230800        69  -0.74  -90.35
# 2           velsk           0      RU  1535235982        81  61.07   42.10
# 3  cabo san lucas          20      MX  1535233680        58  22.89 -109.91
# 4     grand gaube          75      MU  1535234400        69 -20.01   57.66
#
#    Max Temp  Wind Speed
# 0     69.31        5.73
# 1     75.20       16.11
# 2     56.80        7.96
# 3     89.60       10.29
# 4     73.40       14.99

# %%
city_data_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     east london           0      ZA  1535235886        94 -33.02   27.91
# 1    puerto ayora          75      EC  1535230800        69  -0.74  -90.35
# 2           velsk           0      RU  1535235982        81  61.07   42.10
# 3  cabo san lucas          20      MX  1535233680        58  22.89 -109.91
# 4     grand gaube          75      MU  1535234400        69 -20.01   57.66
#
#    Max Temp  Wind Speed
# 0     69.31        5.73
# 1     75.20       16.11
# 2     56.80        7.96
# 3     89.60       10.29
# 4     73.40       14.99

# %%
#create a function to generate a scatter plot
def create_scatter_plot(chartName,x,y,title,xlabel,ylabel):
    
    now = datetime.now()
    now = now.strftime("%m/%Y/%d")
    
    fig = plt.figure(figsize=(18,9))
    plt.grid()
    plt.scatter(x,y,facecolors="blue", edgecolors="black",s=50)
    plt.xlim(-90,90)
    plt.title(f"{title} ({now})",fontsize=(18));
    plt.ylabel(ylabel,fontsize=(15));
    plt.xlabel(xlabel,fontsize=(15));
    plt.savefig(f"{chartName}.png")
    plt.show()

# %%
create_scatter_plot("CityLatitudeVsTemp",city_data_df['Lat'],city_data_df['Max Temp'],'City Latitude vs Max Temperature','Latitude','Max Temperature (F)')

# %%
create_scatter_plot("CityLatitudeVsHumidity",city_data_df['Lat'],city_data_df['Humidity'],'City Latitude vs Humidity','Latitude','Humidity(%)')

# %%
create_scatter_plot("CityLatitudeVsCloudiness",city_data_df['Lat'],city_data_df['Cloudiness'],'City Latitude vs Cloudiness','Latitude','Cloudiness(%)')

# %%
create_scatter_plot("CityLatitudeVsWindSpeed",city_data_df['Lat'],city_data_df['Wind Speed'],'City Latitude vs Windspeed','Latitude','Windspeed(mph)')

# %%
city_data_df.to_csv(output_data_file)
